# %%
import pandas as pd

# %%
pd.read_csv('../datasets/UNEMPLOYMENT RATE 2017.csv', sep = ';', index_col = 0)
# Out:
#                         Unemployment_rate
# Country
# Afghanistan                          1.56
# Albania                             13.75
# Algeria                             12.00
# Angola                               7.14
# Argentina                            8.35
# Armenia                             17.83
# Australia                            5.59
# Austria                              5.50
# Azerbaijan                           5.00
# Bahamas                             12.38
# Bahrain                              0.95
# Bangladesh                           4.37
# Barbados                             9.49
# Belarus                              5.65
# Belgium                              7.09
# Belize                               9.00
# Benin                                2.18
# Bhutan                               2.17
# Bolivia                              2.17
# Bosnia and Herzegovina              20.47
# Botswana                            17.63
# ...
